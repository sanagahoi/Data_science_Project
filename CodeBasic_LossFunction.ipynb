# %%
import numpy as np

y_pred = np.array([1,1,0,0,1])
y_true = np.array([0.7, 0.30,1,0,0.5])

# %%
# without using numpy 

def mae(y_true, y_pred):
    total_error =0
    for yt,yp in zip(y_true, y_pred):
        total_error += abs(yt-yp)
    mae = total_error/len(y_true)
    return mae

# %%
mae = mae(y_true, y_pred)

# %%
print('Mean absolute error: ', mae)
# Out:
# Mean absolute error:  0.5

# %%
# with numpy

(y_pred- y_true)
# Out:
# array([ 0.3,  0.7, -1. ,  0. ,  0.5])

# %%
np.abs(y_pred- y_true)
# Out:
# array([0.3, 0.7, 1. , 0. , 0.5])

# %%
np.mean(np.abs(y_pred- y_true))
# Out:
# 0.5

# %%
# mean squared error - without numpy

def mse(y_true, y_pred):
    total_error = 0
    for yt, yp in zip(y_true, y_pred):
        total_error += (yt-yp)**2
    mse = total_error/len(y_true)
    print('Total error: ', total_error)
    print("Mean squared error : ", mse)

# %%
mse(y_true, y_pred)
# Out:
# Total error:  1.83
# Mean squared error :  0.366

# %%
# with numpy

(y_pred - y_true)**2
# Out:
# array([0.09, 0.49, 1.  , 0.  , 0.25])

# %%
np.square(y_pred - y_true)
# Out:
# array([0.09, 0.49, 1.  , 0.  , 0.25])

# %%
np.sum(np.square(y_pred - y_true))
# Out:
# 1.83

# %%
np.mean(np.square(y_pred - y_true))
# Out:
# 0.366

# %%
#  for log function we need to take value clost to zero but not zero

# for example

np.log(0)      #will give undefined value so need to replace 0 to different values
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_5488\2497729573.py:5: RuntimeWarning: divide by zero encountered in log
#   np.log(0)
# -inf

# %%
np.log([0.0000000000002])
# Out:
# array([-29.24045903])

# %%
epsilon = 1e+15
print(epsilon)

epsilon = 1e-15
print(epsilon)
# Out:
# 1000000000000000.0
# 1e-15

# %%
y_pred
# Out:
# array([1, 1, 0, 0, 1])

# %%
y_pred_new = [max(i, epsilon) for i in y_pred ]
y_pred_new                  #it replaces 0 to close to 0
# Out:
# [1, 1, 1e-15, 1e-15, 1]

# %%
y_pred_new = [min(i,1- epsilon) for i in y_pred_new ]
y_pred_new
# Out:
# [0.999999999999999, 0.999999999999999, 1e-15, 1e-15, 0.999999999999999]

# %%
y_pred_new = np.array(y_pred_new)
y_pred_new               #list to numpy array to remove infinite value
# Out:
# array([1.e+00, 1.e+00, 1.e-15, 1.e-15, 1.e+00])

# %%
np.log(y_pred_new)
# Out:
# array([-9.99200722e-16, -9.99200722e-16, -3.45387764e+01, -3.45387764e+01,
#        -9.99200722e-16])

# %%
np.log(y_pred)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_5488\4184140517.py:1: RuntimeWarning: divide by zero encountered in log
#   np.log(y_pred)
# array([  0.,   0., -inf, -inf,   0.])

# %%
# log loss

-np.mean(y_true*np.log(y_pred_new) +(1-y_true)*np.log(1-y_pred_new))
# Out:
# 17.2696280766844

# %%
def log_loss(y_true, y_pred):
    epsilon = 1e-15
    y_pred_new = [max(i, epsilon) for i in y_pred]
    y_pred_new = [min(i, 1-epsilon) for i in y_pred_new]
    y_pred_new = np.array(y_pred_new)
    ll = -np.mean(y_true*np.log(y_pred_new)+(1-y_true)*np.log(1-y_pred_new))
    return ll

# %%
log_loss(y_true, y_pred)
# Out:
# 17.2696280766844
